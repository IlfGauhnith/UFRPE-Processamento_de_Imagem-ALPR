# %% [markdown]
# # Setup
# - packages installation
# - imports

# %%
# %pip install numpy pandas matplotlib opencv-python
# Out:
# Requirement already satisfied: numpy in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (1.25.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (3.7.2)
# Requirement already satisfied: opencv-python in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (4.8.0.76)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from matplotlib) (6.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\lucas\bcc\alpr\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# %pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import os
import random

# %% [markdown]
# # UTIL

# %%
DATASET_CARS_BR_PATH = "./dataset_RodoSol-ALPR/images/cars-br" # Path to images of cars with old license plate model
DATASET_CARS_ME_PATH = "./dataset_RodoSol-ALPR/images/cars-me" # Path to images of cars with MERCOSUL license plate model
DATASET_MOTORCYCLES_BR_PATH = "./dataset_RodoSol-ALPR/images/motorcycles-br" # Path to images of motorcycles with old license plate model
DATASET_MOTORCYCLES_ME_PATH = "./dataset_RodoSol-ALPR/images/motorcycles-me" # Path to images of motorcycles with MERCOSUL license plate model

VERBOSE = True
DEV_MODE = False

# %%
def verbose_decorator(func):
    def wrapper(*args, **kwargs):
        if VERBOSE:
            print()
            print(func)
        return func(*args, **kwargs)
    return wrapper

# %%
@verbose_decorator
def unit_exec(image_path, save_path, algorithm, algorithm_args):
    """
    unit_exec does a test for dev purposes. It receives two paths. First path is where the image to be processed is.
    The second one is where to save it. This function is for comparing algorithms and its parameters.
    """
    image = cv2.imread(image_path)
    image = algorithm(image, **algorithm_args)
    cv2.imwrite(save_path, image)

# %%
@verbose_decorator
def sample_images(data_path: str, exclude_path: str, sample_size=None) -> list[tuple]:
    """
    sample_images randomly chooses a number of images, equal to the parameter sample_size, from a directory specified by data_path 
    excluding images already at directory specified by exclude_path. If sample_size is None then pick all images from directory.
    It returns a list containing tuples, each tuple with a opencv image and its OS path.
    """
    
    if exclude_path == "" or exclude_path is None: # If not informed then ignore excluding.
        excluded_images = []
    else:
        excluded_images= [data_path + '/' + file_name for file_name in os.listdir(exclude_path) if file_name.endswith(".jpg")]

    image_paths = [data_path + '/' + file_name for file_name in os.listdir(data_path) if file_name.endswith(".jpg") and file_name not in excluded_images]
    if sample_size is not None:
        image_paths = random.sample(image_paths, min(sample_size, len(image_paths)))
    
    images = [(cv2.imread(image_path), image_path) for image_path in image_paths]
    if VERBOSE:
        print(f"Excluded files from sampling: {excluded_images}")
        print(f"Sampled files: {image_paths}")
        
    
    return images

# %%
@verbose_decorator
def combine_images_side_by_side(image1, image2):
    # Determine the maximum height of the two images
    max_height = max(image1.shape[0], image2.shape[0])
    
    # Create a canvas with white background
    combined_height = max_height
    combined_width = image1.shape[1] + image2.shape[1]
    combined_image = np.ones((combined_height, combined_width, 3), dtype=np.uint8) * 255  # Fill with white (255, 255, 255)
    
    # Paste the first image onto the canvas
    combined_image[:image1.shape[0], :image1.shape[1]] = image1
    
    # Paste the second image onto the canvas, starting from the width of the first image
    combined_image[:image2.shape[0], image1.shape[1]:] = image2
    
    return combined_image

@verbose_decorator
def compare_and_save(original_images, processed_images, save_path):
   os.makedirs(save_path, exist_ok=True) # Create directory and dont raise error if already exists
   
   images = [(orig, proc) for orig, proc in zip(original_images, processed_images)]

   for orig, proc in images:
       combined_images = combine_images_side_by_side(orig[0], proc[0])
       image_save_path = save_path + '/' + orig[1].split('/')[-1]
       cv2.imwrite(image_save_path, combined_images)
       
       if VERBOSE:
            print(f"{orig[1].split('/')[-1]} saved at {image_save_path}")

# %%
@verbose_decorator
def show_comparison(original_images, processed_images):
    """
    show_comparison shows a comparison side by side between original_images and processed_images
    """
    images = [(orig, proc) for orig, proc in zip(original_images, processed_images)]
    if VERBOSE:
        print(f"images zipped structure: {[(orig[1], proc[1]) for orig, proc in images]}")
        for orig, proc in images:
            print(f"{orig[1].split('/')[-1]} shape: {orig[0].shape}")
            print(f"{proc[1]} shape: {proc[0].shape}")
    
    fig, axes = plt.subplots(len(images), 2, figsize=(20, 10))
    ax = axes.ravel()
    
    ax_i = -1
    for orig, proc in images:
        ax_i += 1
        ax[ax_i].imshow(orig[0])
        ax[ax_i].set_title(orig[1].split('/')[-1] + " Original")
        ax[ax_i].set_axis_off()
        
        ax_i += 1
        ax[ax_i].imshow(proc[0])
        ax[ax_i].set_title(proc[1].split('/')[-1] + " Processed")
        ax[ax_i].set_axis_off()

# %%
@verbose_decorator
def sample_execute_save_show(data_path: str, save_path: str, algorithm: callable, algorithm_args: dict, show=False, pre_sample=None, sample_size=None):
    """
    sample_execute_save_show randomly sample images from directory specified by data_path ignoring 
    images already at directory specified by save_path, execute a algorithm of image processing which must return a single image,
    save processed images at a directory specified by save_path and then shows a comparison between the original and processed image.
    If presample contains a valid images names list then execute algorithm with this images.
    If sample_size is None then execute algorithm on the entire directory.
    """
    os.makedirs(save_path, exist_ok=True) # Create directory and dont raise error if already exists
    is_pre_sample = isinstance(pre_sample, list) and all([sample in os.listdir(data_path) for sample in pre_sample]) # If is a list and directory specified by data_path contain ALL samples.
    
    if VERBOSE:
        print(f"is pre sampled: {is_pre_sample}")
    
    # Defining algorithm input scope
    if is_pre_sample: # Images pre sampled
        original_images = pre_sample
    elif sample_size is None:
        original_images = sample_images(data_path, save_path, sample_size=None)
    else: # Sample Images
        original_images = sample_images(data_path, save_path, sample_size)

    processed_images = []
    for original_image, path in original_images:
        image_save_path = save_path + '/' + path.split('/')[-1]

        processed_image = algorithm(original_image, **algorithm_args)
        processed_images.append( (processed_image, image_save_path) )

        cv2.imwrite(image_save_path, processed_image)
        if VERBOSE:
            print(f"{path.split('/')[-1]} saved at {image_save_path}")

    if show:
        show_comparison(original_images, processed_images)

    return processed_images

# %% [markdown]
# # Applying Grayscale, equalizing histogram and normalizing brightness

# %%
SAVE_CARS_BR_GRAYSCALE_PATH = "./output/images/grayscale/cars-br" # Save path to images of cars with old license plate model converted to grayscale
SAVE_CARS_ME_GRAYSCALE_PATH = "./output/images/grayscale/cars-me" # Save path to images of cars with MERCOSUL license plate model converted to grayscale
SAVE_MOTORCYCLES_BR_GRAYSCALE_PATH = "./output/images/grayscale/motorcycles-br" # Save path to images of motorcycles with old license plate model converted to grayscale
SAVE_MOTORCYCLES_ME_GRAYSCALE_PATH = "./output/images/grayscale/motorcycles-me" # Save path to images of motorcycles with MERCOSUL license plate model converted to grayscale


SAVE_CARS_BR_HISTEQ_PATH = "./output/images/histeq/cars-br" # Save path to images of cars with old license plate model with histogram equalized
SAVE_CARS_ME_HISTEQ_PATH = "./output/images/histeq/cars-me" # Save path to images of cars with MERCOSUL license plate model with histogram equalized
SAVE_MOTORCYCLES_BR_HISTEQ_PATH = "./output/images/histeq/motorcycles-br" # Save path to images of motorcycles with old license plate model with histogram equalized
SAVE_MOTORCYCLES_ME_HISTEQ_PATH = "./output/images/histeq/motorcycles-me" # Save path to images of motorcycles with MERCOSUL license plate model with histogram equalized

# %%
def convert_to_grayscale(image):
    """
    Convert an OpenCV image to grayscale.

    Args:
        image (numpy.ndarray): The input OpenCV image.

    Returns:
        numpy.ndarray: The grayscale image.
    """
    grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return grayscale_image

# %%
def equalize_histogram(image):
    grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    equalized_image = cv2.equalizeHist(grayscale_image)
    
    return equalized_image

# %%
if not DEV_MODE and not os.path.exists("./output/images/grayscale/"): # If grayscale was not executed yet
    # GRAYSCALE
    _ = sample_execute_save_show(data_path=DATASET_CARS_BR_PATH, 
                                save_path=SAVE_CARS_BR_GRAYSCALE_PATH,
                                algorithm=convert_to_grayscale,
                                algorithm_args=dict())

    _ = sample_execute_save_show(data_path=DATASET_CARS_ME_PATH, 
                                save_path=SAVE_CARS_ME_GRAYSCALE_PATH,
                                algorithm=convert_to_grayscale,
                                algorithm_args=dict())

    _ = sample_execute_save_show(data_path=DATASET_MOTORCYCLES_BR_PATH, 
                                save_path=SAVE_MOTORCYCLES_BR_GRAYSCALE_PATH,
                                algorithm=convert_to_grayscale,
                                algorithm_args=dict())

    _ = sample_execute_save_show(data_path=DATASET_MOTORCYCLES_ME_PATH, 
                                save_path=SAVE_MOTORCYCLES_ME_GRAYSCALE_PATH,
                                algorithm=convert_to_grayscale,
                                algorithm_args=dict())

# %%
if not DEV_MODE and not os.path.exists("./output/images/histeq/"): # If histogram equalization was not executed yet
    # EQUALIZING HISTOGRAM
    _ = sample_execute_save_show(data_path=SAVE_CARS_BR_GRAYSCALE_PATH, 
                                save_path=SAVE_CARS_BR_HISTEQ_PATH,
                                algorithm=equalize_histogram,
                                algorithm_args=dict())

    _ = sample_execute_save_show(data_path=SAVE_CARS_ME_GRAYSCALE_PATH, 
                                save_path=SAVE_CARS_ME_HISTEQ_PATH,
                                algorithm=equalize_histogram,
                                algorithm_args=dict())

    _ = sample_execute_save_show(data_path=SAVE_MOTORCYCLES_BR_GRAYSCALE_PATH, 
                                save_path=SAVE_MOTORCYCLES_BR_HISTEQ_PATH,
                                algorithm=equalize_histogram,
                                algorithm_args=dict())

    _ = sample_execute_save_show(data_path=SAVE_MOTORCYCLES_ME_GRAYSCALE_PATH, 
                                save_path=SAVE_MOTORCYCLES_ME_HISTEQ_PATH,
                                algorithm=equalize_histogram,
                                algorithm_args=dict())

# %% [markdown]
# # Downscaling

# %%
SAVE_CARS_BR_DOWNSCALING_PATH = "./output/images/downscaling/cars-br" # Save path to downscaled images of cars with old license plate model
SAVE_CARS_ME_DOWNSCALING_PATH = "./output/images/downscaling/cars-me" # Save path to downscaled images of cars with MERCOSUL license plate model
SAVE_MOTORCYCLES_BR_DOWNSCALING_PATH = "./output/images/downscaling/motorcycles-br" # Save path to downscaled images of motorcycles with old license plate model
SAVE_MOTORCYCLES_ME_DOWNSCALING_PATH = "./output/images/downscaling/motorcycles-me" # Save path to downscaled images of motorcycles with MERCOSUL license plate model

DOWNSCALING_RATIO = 0.75

# %%
@verbose_decorator
def resize(image, ratio, interpolation_method_name, flag):
    width = int(image.shape[1] * ratio)
    height = int(image.shape[0] * ratio)
    dim = (width, height)

    if VERBOSE:
        print(f"interpolation method: {interpolation_method_name}")
        print(f"downscaling ratio: {str(ratio)}")
        print(f"original image shape: {image.shape}")
        print(f"new shape: {dim}")
        
    return cv2.resize(image, dim, interpolation=flag)

# %%
INTERPOLATION_FLAGS = [
    ('bilinear', cv2.INTER_LINEAR),
    ('bicubic', cv2.INTER_CUBIC),
    ('lanczos', cv2.INTER_LANCZOS4)
]

if not DEV_MODE and not os.path.exists("./output/images/downscaling/"): # If grayscale was not executed yet
    _ = sample_execute_save_show(data_path=SAVE_CARS_BR_HISTEQ_PATH, 
                                    save_path=SAVE_CARS_BR_DOWNSCALING_PATH,
                                    algorithm=resize, 
                                    algorithm_args={"ratio": DOWNSCALING_RATIO, "interpolation_method_name": INTERPOLATION_FLAGS[2][0], "flag": INTERPOLATION_FLAGS[2][1]})

    _ = sample_execute_save_show(data_path=SAVE_CARS_ME_HISTEQ_PATH, 
                                    save_path=SAVE_CARS_ME_DOWNSCALING_PATH,
                                    algorithm=resize, 
                                    algorithm_args={"ratio": DOWNSCALING_RATIO, "interpolation_method_name": INTERPOLATION_FLAGS[2][0], "flag": INTERPOLATION_FLAGS[2][1]})

    _ = sample_execute_save_show(data_path=SAVE_MOTORCYCLES_BR_HISTEQ_PATH, 
                                    save_path=SAVE_MOTORCYCLES_BR_DOWNSCALING_PATH,
                                    algorithm=resize, 
                                    algorithm_args={"ratio": DOWNSCALING_RATIO, "interpolation_method_name": INTERPOLATION_FLAGS[2][0], "flag": INTERPOLATION_FLAGS[2][1]})

    _ = sample_execute_save_show(data_path=SAVE_MOTORCYCLES_ME_HISTEQ_PATH, 
                                    save_path=SAVE_MOTORCYCLES_ME_DOWNSCALING_PATH,
                                    algorithm=resize, 
                                    algorithm_args={"ratio": DOWNSCALING_RATIO, "interpolation_method_name": INTERPOLATION_FLAGS[2][0], "flag": INTERPOLATION_FLAGS[2][1]})

# %% [markdown]
# # Noise Reduction

# %%
SAVE_CARS_BR_NOISEREDUCTION_PATH = "./output/images/noisereduction/cars-br" # Save path to noise reducted images of cars with old license plate model
SAVE_CARS_ME_NOISEREDUCTION_PATH = "./output/images/noisereduction/cars-me" # Save path to noise reducted images of cars with MERCOSUL license plate model
SAVE_MOTORCYCLES_BR_NOISEREDUCTION_PATH = "./output/images/noisereduction/motorcycles-br" # Save path to noise reducted images of motorcycles with old license plate model
SAVE_MOTORCYCLES_ME_NOISEREDUCTION_PATH = "./output/images/noisereduction/motorcycles-me" # Save path to noise reducted images of motorcycles with MERCOSUL license plate model

# %%
def reduce_noise(image, algorithm, algorithm_args):
    return algorithm(image, **algorithm_args)

# %%
if DEV_MODE:
    cv2.imwrite("./output/images/test/img_000082.jpg", cv2.imread("./dataset_RodoSol-ALPR/images/cars-br/img_000082.jpg"))

    # median blur
    unit_exec(image_path="./output/images/downscaling/cars-br/img_000082.jpg",
                save_path="./output/images/test/img_000082_medianblur.jpg",
                algorithm=cv2.medianBlur,
                algorithm_args={"ksize":5})
    
    # gaussian blur
    unit_exec(image_path="./output/images/downscaling/cars-br/img_000082.jpg",
            save_path="./output/images/test/img_000082_gaussianblur.jpg",
            algorithm=cv2.GaussianBlur,
            algorithm_args={"ksize": (5,5), "sigmaX": 0})
    
    # Non-Local Means (NLM) 
    unit_exec(image_path="./output/images/downscaling/cars-br/img_000082.jpg",
            save_path="./output/images/test/img_000082_NLM.jpg",
            algorithm=cv2.fastNlMeansDenoising,
            algorithm_args={"h": 5, "templateWindowSize": 7, "searchWindowSize": 21})

# %%
if not DEV_MODE and not os.path.exists("./output/images/noisereduction/"): # If grayscale was not executed yet
    _ = sample_execute_save_show(data_path=SAVE_CARS_BR_DOWNSCALING_PATH, 
                                    save_path=SAVE_CARS_BR_NOISEREDUCTION_PATH,
                                    algorithm=reduce_noise, 
                                    algorithm_args={"algorithm": cv2.fastNlMeansDenoising, "algorithm_args": {"h": 5, "templateWindowSize": 7, "searchWindowSize": 21}})

    _ = sample_execute_save_show(data_path=SAVE_CARS_ME_DOWNSCALING_PATH, 
                                    save_path=SAVE_CARS_ME_NOISEREDUCTION_PATH,
                                    algorithm=reduce_noise, 
                                    algorithm_args={"algorithm": cv2.fastNlMeansDenoising, "algorithm_args": {"h": 5, "templateWindowSize": 7, "searchWindowSize": 21}})

    _ = sample_execute_save_show(data_path=SAVE_MOTORCYCLES_BR_DOWNSCALING_PATH, 
                                    save_path=SAVE_MOTORCYCLES_BR_NOISEREDUCTION_PATH,
                                    algorithm=reduce_noise, 
                                    algorithm_args={"algorithm": cv2.fastNlMeansDenoising, "algorithm_args": {"h": 5, "templateWindowSize": 7, "searchWindowSize": 21}})

    _ = sample_execute_save_show(data_path=SAVE_MOTORCYCLES_ME_DOWNSCALING_PATH, 
                                    save_path=SAVE_MOTORCYCLES_ME_NOISEREDUCTION_PATH,
                                    algorithm=reduce_noise, 
                                    algorithm_args={"algorithm": cv2.fastNlMeansDenoising, "algorithm_args": {"h": 5, "templateWindowSize": 7, "searchWindowSize": 21}})

# %% [markdown]
# # Comparing
# Comparing original and processed images

# %%
SAVE_CARS_BR_COMPARING_PATH = "./output/images/comparing/cars-br"
SAVE_CARS_ME_COMPARING_PATH = "./output/images/comparing/cars-me"
SAVE_MOTORCYCLES_BR_COMPARING_PATH = "./output/images/comparing/motorcycles-br"
SAVE_MOTORCYCLES_ME_COMPARING_PATH = "./output/images/comparing/motorcycles-me"

# %%
original_images = sample_images(data_path=DATASET_CARS_BR_PATH, exclude_path="")
processed_images = sample_images(data_path=SAVE_CARS_BR_NOISEREDUCTION_PATH, exclude_path="")

compare_and_save(original_images, processed_images, SAVE_CARS_BR_COMPARING_PATH)
# Out:
# <function sample_images at 0x000001FADFF30DC0>
# Excluded files from sampling: []
# Sampled files: ['./dataset_RodoSol-ALPR/images/cars-br/img_000001.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000002.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000003.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000004.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000005.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000006.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000007.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000008.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000009.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000010.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000011.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000012.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000013.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000014.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000015.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000016.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000017.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000018.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000019.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000020.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000021.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000022.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000023.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000024.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000025.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000026.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000027.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000028.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000029.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000030.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000031.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000032.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000033.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000034.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000035.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000036.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000037.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000038.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000039.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000040.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000041.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000042.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000043.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000044.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000045.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000046.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000047.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000048.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000049.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000050.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000051.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000052.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000053.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000054.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000055.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000056.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000057.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000058.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000059.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000060.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000061.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000062.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000063.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000064.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000065.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000066.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000067.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000068.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000069.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000070.jpg', './dataset_RodoSol-ALPR/images/cars-br/img_000071.jpg', './datas ...
#
# <function sample_images at 0x000001FADFF30DC0>
# Excluded files from sampling: []
# Sampled files: ['./output/images/noisereduction/cars-br/img_000001.jpg', './output/images/noisereduction/cars-br/img_000002.jpg', './output/images/noisereduction/cars-br/img_000003.jpg', './output/images/noisereduction/cars-br/img_000004.jpg', './output/images/noisereduction/cars-br/img_000005.jpg', './output/images/noisereduction/cars-br/img_000006.jpg', './output/images/noisereduction/cars-br/img_000007.jpg', './output/images/noisereduction/cars-br/img_000008.jpg', './output/images/noisereduction/cars-br/img_000009.jpg', './output/images/noisereduction/cars-br/img_000010.jpg', './output/images/noisereduction/cars-br/img_000011.jpg', './output/images/noisereduction/cars-br/img_000012.jpg', './output/images/noisereduction/cars-br/img_000013.jpg', './output/images/noisereduction/cars-br/img_000014.jpg', './output/images/noisereduction/cars-br/img_000015.jpg', './output/images/noisereduction/cars-br/img_000016.jpg', './output/images/noisereduction/cars-br/img_000017.jpg', './output/images/noisereduction/cars-br/img_000018.jpg', './output/images/noisereduction/cars-br/img_000019.jpg', './output/images/noisereduction/cars-br/img_000020.jpg', './output/images/noisereduction/cars-br/img_000021.jpg', './output/images/noisereduction/cars-br/img_000022.jpg', './output/images/noisereduction/cars-br/img_000023.jpg', './output/images/noisereduction/cars-br/img_000024.jpg', './output/images/noisereduction/cars-br/img_000025.jpg', './output/images/noisereduction/cars-br/img_000026.jpg', './output/images/noisereduction/cars-br/img_000027.jpg', './output/images/noisereduction/cars-br/img_000028.jpg', './output/images/noisereduction/cars-br/img_000029.jpg', './output/images/noisereduction/cars-br/img_000030.jpg', './output/images/noisereduction/cars-br/img_000031.jpg', './output/images/noisereduction/cars-br/img_000032.jpg', './output/images/noisereduction/cars-br/img_000033.jpg', './output/images/noisereduction/cars-br/img_000034.jpg', './output/images/noisereduction/cars-br/img_000035.jpg', './output/images/noisereduction/cars-br/img_000036.jpg', './output/images/noisereduction/cars-br/img_000037.jpg', './output/images/noisereduction/cars-br/img_000038.jpg', './output/images/noisereduction/cars-br/img_000039.jpg', './output/images/noisereduction/cars-br/img_000040.jpg', './output/images/noisereduction/cars-br/img_000041.jpg', './output/images/noisereduction/cars-br/img_000042.jpg', './output/images/noisereduction/cars-br/img_000043.jpg', './output/images/noisereduction/cars-br/img_000044.jpg', './output/images/noisereduction/cars-br/img_000045.jpg', './output/images/noisereduction/cars-br/img_000046.jpg', './output/images/noisereduction/cars-br/img_000047.jpg', './output/images/noisereduction/cars-br/img_000048.jpg', './output/images/noisereduction/cars-br/img_000049.jpg', './output/images/noisereduction/cars-br/img_000050.jpg', './output/images/noisereduction/cars-br/img_000051.jpg', './output/images/noisereduction/cars-br/img_000052.jpg', './output/images/noisereduction/cars-br/img_000053.jpg', './output/images/noisereduction/cars-br/img_000054.jpg', './output/images/noisereduction/cars-br/img_000055.jpg', './output/images/noisereduction/cars-br/img_000056.jpg', './output/images/noisereduction/cars-br/img_000057.jpg', './output/images/noisereduction/cars-br/img_000058.jpg', './output/images/noisereduction/cars-br/img_000059.jpg', './output/images/noisereduction/cars-br/img_000060.jpg', './output/images/noisereduction/cars-br/img_000061.jpg', './output/images/noisereduction/cars-br/img_000062.jpg', './output/images/noisereduction/cars-br/img_000063.jpg', './output/images/noisereduction/cars-br/img_000064.jpg', './output/images/noisereduction/cars-br/img_000065.jpg', './output/images/noisereduction/cars-br/img_000066.jpg', './output/images/noisereduction/cars-br/img_000067.jpg', './output/images/noisereduction/cars-br/img_000068.jpg', './output/images/noisereduction/cars-br/img_000069.jpg', './output/images/noisereduction/cars-br/img_000070. ...
#
# <function compare_and_save at 0x000001FADFF30B80>
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000001.jpg saved at ./output/images/comparing/cars-br/img_000001.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000002.jpg saved at ./output/images/comparing/cars-br/img_000002.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000003.jpg saved at ./output/images/comparing/cars-br/img_000003.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000004.jpg saved at ./output/images/comparing/cars-br/img_000004.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000005.jpg saved at ./output/images/comparing/cars-br/img_000005.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000006.jpg saved at ./output/images/comparing/cars-br/img_000006.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000007.jpg saved at ./output/images/comparing/cars-br/img_000007.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000008.jpg saved at ./output/images/comparing/cars-br/img_000008.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000009.jpg saved at ./output/images/comparing/cars-br/img_000009.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000010.jpg saved at ./output/images/comparing/cars-br/img_000010.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000011.jpg saved at ./output/images/comparing/cars-br/img_000011.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000012.jpg saved at ./output/images/comparing/cars-br/img_000012.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000013.jpg saved at ./output/images/comparing/cars-br/img_000013.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000014.jpg saved at ./output/images/comparing/cars-br/img_000014.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000015.jpg saved at ./output/images/comparing/cars-br/img_000015.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000016.jpg saved at ./output/images/comparing/cars-br/img_000016.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000017.jpg saved at ./output/images/comparing/cars-br/img_000017.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000018.jpg saved at ./output/images/comparing/cars-br/img_000018.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000019.jpg saved at ./output/images/comparing/cars-br/img_000019.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000020.jpg saved at ./output/images/comparing/cars-br/img_000020.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000021.jpg saved at ./output/images/comparing/cars-br/img_000021.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000022.jpg saved at ./output/images/comparing/cars-br/img_000022.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000023.jpg saved at ./output/images/comparing/cars-br/img_000023.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000024.jpg saved at ./output/images/comparing/cars-br/img_000024.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000025.jpg saved at ./output/images/comparing/cars-br/img_000025.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000026.jpg saved at ./output/images/comparing/cars-br/img_000026.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000027.jpg saved at ./output/images/comparing/cars-br/img_000027.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000028.jpg saved at ./output/images/comparing/cars-br/img_000028.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000029.jpg saved at ./output/images/comparing/cars-br/img_000029.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000030.jpg saved at ./output/images/comparing/cars-br/img_000030.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000031.jpg saved at ./output/images/comparing/cars-br/img_000031.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000032.jpg saved at ./output/images/comparing/cars-br/img_000032.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000033.jpg saved at ./output/images/comparing/cars-br/img_000033.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000034.jpg saved at ./output/images/comparing/cars-br/img_000034.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000035.jpg saved at ./output/images/comparing/cars-br/img_000035.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000036.jpg saved at ./output/images/comparing/cars-br/img_000036.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000037.jpg saved at ./output/images/comparing/cars-br/img_000037.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000038.jpg saved at ./output/images/comparing/cars-br/img_000038.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000039.jpg saved at ./output/images/comparing/cars-br/img_000039.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000040.jpg saved at ./output/images/comparing/cars-br/img_000040.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000041.jpg saved at ./output/images/comparing/cars-br/img_000041.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000042.jpg saved at ./output/images/comparing/cars-br/img_000042.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000043.jpg saved at ./output/images/comparing/cars-br/img_000043.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000044.jpg saved at ./output/images/comparing/cars-br/img_000044.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000045.jpg saved at ./output/images/comparing/cars-br/img_000045.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000046.jpg saved at ./output/images/comparing/cars-br/img_000046.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000047.jpg saved at ./output/images/comparing/cars-br/img_000047.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000048.jpg saved at ./output/images/comparing/cars-br/img_000048.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000049.jpg saved at ./output/images/comparing/cars-br/img_000049.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000050.jpg saved at ./output/images/comparing/cars-br/img_000050.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000051.jpg saved at ./output/images/comparing/cars-br/img_000051.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000052.jpg saved at ./output/images/comparing/cars-br/img_000052.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000053.jpg saved at ./output/images/comparing/cars-br/img_000053.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000054.jpg saved at ./output/images/comparing/cars-br/img_000054.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000055.jpg saved at ./output/images/comparing/cars-br/img_000055.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000056.jpg saved at ./output/images/comparing/cars-br/img_000056.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000057.jpg saved at ./output/images/comparing/cars-br/img_000057.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000058.jpg saved at ./output/images/comparing/cars-br/img_000058.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000059.jpg saved at ./output/images/comparing/cars-br/img_000059.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000060.jpg saved at ./output/images/comparing/cars-br/img_000060.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000061.jpg saved at ./output/images/comparing/cars-br/img_000061.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000062.jpg saved at ./output/images/comparing/cars-br/img_000062.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000063.jpg saved at ./output/images/comparing/cars-br/img_000063.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000064.jpg saved at ./output/images/comparing/cars-br/img_000064.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000065.jpg saved at ./output/images/comparing/cars-br/img_000065.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000066.jpg saved at ./output/images/comparing/cars-br/img_000066.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000067.jpg saved at ./output/images/comparing/cars-br/img_000067.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000068.jpg saved at ./output/images/comparing/cars-br/img_000068.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000069.jpg saved at ./output/images/comparing/cars-br/img_000069.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000070.jpg saved at ./output/images/comparing/cars-br/img_000070.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000071.jpg saved at ./output/images/comparing/cars-br/img_000071.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000072.jpg saved at ./output/images/comparing/cars-br/img_000072.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000073.jpg saved at ./output/images/comparing/cars-br/img_000073.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000074.jpg saved at ./output/images/comparing/cars-br/img_000074.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000075.jpg saved at ./output/images/comparing/cars-br/img_000075.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000076.jpg saved at ./output/images/comparing/cars-br/img_000076.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000077.jpg saved at ./output/images/comparing/cars-br/img_000077.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000078.jpg saved at ./output/images/comparing/cars-br/img_000078.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000079.jpg saved at ./output/images/comparing/cars-br/img_000079.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000080.jpg saved at ./output/images/comparing/cars-br/img_000080.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000081.jpg saved at ./output/images/comparing/cars-br/img_000081.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000082.jpg saved at ./output/images/comparing/cars-br/img_000082.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000083.jpg saved at ./output/images/comparing/cars-br/img_000083.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000084.jpg saved at ./output/images/comparing/cars-br/img_000084.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000085.jpg saved at ./output/images/comparing/cars-br/img_000085.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000086.jpg saved at ./output/images/comparing/cars-br/img_000086.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000087.jpg saved at ./output/images/comparing/cars-br/img_000087.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000088.jpg saved at ./output/images/comparing/cars-br/img_000088.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000089.jpg saved at ./output/images/comparing/cars-br/img_000089.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000090.jpg saved at ./output/images/comparing/cars-br/img_000090.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000091.jpg saved at ./output/images/comparing/cars-br/img_000091.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000092.jpg saved at ./output/images/comparing/cars-br/img_000092.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000093.jpg saved at ./output/images/comparing/cars-br/img_000093.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000094.jpg saved at ./output/images/comparing/cars-br/img_000094.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000095.jpg saved at ./output/images/comparing/cars-br/img_000095.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000096.jpg saved at ./output/images/comparing/cars-br/img_000096.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000097.jpg saved at ./output/images/comparing/cars-br/img_000097.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000098.jpg saved at ./output/images/comparing/cars-br/img_000098.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000099.jpg saved at ./output/images/comparing/cars-br/img_000099.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000100.jpg saved at ./output/images/comparing/cars-br/img_000100.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000101.jpg saved at ./output/images/comparing/cars-br/img_000101.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000102.jpg saved at ./output/images/comparing/cars-br/img_000102.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000103.jpg saved at ./output/images/comparing/cars-br/img_000103.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000104.jpg saved at ./output/images/comparing/cars-br/img_000104.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000105.jpg saved at ./output/images/comparing/cars-br/img_000105.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000106.jpg saved at ./output/images/comparing/cars-br/img_000106.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000107.jpg saved at ./output/images/comparing/cars-br/img_000107.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000108.jpg saved at ./output/images/comparing/cars-br/img_000108.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000109.jpg saved at ./output/images/comparing/cars-br/img_000109.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000110.jpg saved at ./output/images/comparing/cars-br/img_000110.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000111.jpg saved at ./output/images/comparing/cars-br/img_000111.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000112.jpg saved at ./output/images/comparing/cars-br/img_000112.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000113.jpg saved at ./output/images/comparing/cars-br/img_000113.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000114.jpg saved at ./output/images/comparing/cars-br/img_000114.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000115.jpg saved at ./output/images/comparing/cars-br/img_000115.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000116.jpg saved at ./output/images/comparing/cars-br/img_000116.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000117.jpg saved at ./output/images/comparing/cars-br/img_000117.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000118.jpg saved at ./output/images/comparing/cars-br/img_000118.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000119.jpg saved at ./output/images/comparing/cars-br/img_000119.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000120.jpg saved at ./output/images/comparing/cars-br/img_000120.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000121.jpg saved at ./output/images/comparing/cars-br/img_000121.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000122.jpg saved at ./output/images/comparing/cars-br/img_000122.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000123.jpg saved at ./output/images/comparing/cars-br/img_000123.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000124.jpg saved at ./output/images/comparing/cars-br/img_000124.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000125.jpg saved at ./output/images/comparing/cars-br/img_000125.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000126.jpg saved at ./output/images/comparing/cars-br/img_000126.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000127.jpg saved at ./output/images/comparing/cars-br/img_000127.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000128.jpg saved at ./output/images/comparing/cars-br/img_000128.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000129.jpg saved at ./output/images/comparing/cars-br/img_000129.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000130.jpg saved at ./output/images/comparing/cars-br/img_000130.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000131.jpg saved at ./output/images/comparing/cars-br/img_000131.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000132.jpg saved at ./output/images/comparing/cars-br/img_000132.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000133.jpg saved at ./output/images/comparing/cars-br/img_000133.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000134.jpg saved at ./output/images/comparing/cars-br/img_000134.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000135.jpg saved at ./output/images/comparing/cars-br/img_000135.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000136.jpg saved at ./output/images/comparing/cars-br/img_000136.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000137.jpg saved at ./output/images/comparing/cars-br/img_000137.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000138.jpg saved at ./output/images/comparing/cars-br/img_000138.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000139.jpg saved at ./output/images/comparing/cars-br/img_000139.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000140.jpg saved at ./output/images/comparing/cars-br/img_000140.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000141.jpg saved at ./output/images/comparing/cars-br/img_000141.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000142.jpg saved at ./output/images/comparing/cars-br/img_000142.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000143.jpg saved at ./output/images/comparing/cars-br/img_000143.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000144.jpg saved at ./output/images/comparing/cars-br/img_000144.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000145.jpg saved at ./output/images/comparing/cars-br/img_000145.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000146.jpg saved at ./output/images/comparing/cars-br/img_000146.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000147.jpg saved at ./output/images/comparing/cars-br/img_000147.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000148.jpg saved at ./output/images/comparing/cars-br/img_000148.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000149.jpg saved at ./output/images/comparing/cars-br/img_000149.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000150.jpg saved at ./output/images/comparing/cars-br/img_000150.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000151.jpg saved at ./output/images/comparing/cars-br/img_000151.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000152.jpg saved at ./output/images/comparing/cars-br/img_000152.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000153.jpg saved at ./output/images/comparing/cars-br/img_000153.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000154.jpg saved at ./output/images/comparing/cars-br/img_000154.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000155.jpg saved at ./output/images/comparing/cars-br/img_000155.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000156.jpg saved at ./output/images/comparing/cars-br/img_000156.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000157.jpg saved at ./output/images/comparing/cars-br/img_000157.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000158.jpg saved at ./output/images/comparing/cars-br/img_000158.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000159.jpg saved at ./output/images/comparing/cars-br/img_000159.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000160.jpg saved at ./output/images/comparing/cars-br/img_000160.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000161.jpg saved at ./output/images/comparing/cars-br/img_000161.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000162.jpg saved at ./output/images/comparing/cars-br/img_000162.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000163.jpg saved at ./output/images/comparing/cars-br/img_000163.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000164.jpg saved at ./output/images/comparing/cars-br/img_000164.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000165.jpg saved at ./output/images/comparing/cars-br/img_000165.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000166.jpg saved at ./output/images/comparing/cars-br/img_000166.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000167.jpg saved at ./output/images/comparing/cars-br/img_000167.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000168.jpg saved at ./output/images/comparing/cars-br/img_000168.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000169.jpg saved at ./output/images/comparing/cars-br/img_000169.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000170.jpg saved at ./output/images/comparing/cars-br/img_000170.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000171.jpg saved at ./output/images/comparing/cars-br/img_000171.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000172.jpg saved at ./output/images/comparing/cars-br/img_000172.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000173.jpg saved at ./output/images/comparing/cars-br/img_000173.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000174.jpg saved at ./output/images/comparing/cars-br/img_000174.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000175.jpg saved at ./output/images/comparing/cars-br/img_000175.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000176.jpg saved at ./output/images/comparing/cars-br/img_000176.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000177.jpg saved at ./output/images/comparing/cars-br/img_000177.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000178.jpg saved at ./output/images/comparing/cars-br/img_000178.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000179.jpg saved at ./output/images/comparing/cars-br/img_000179.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000180.jpg saved at ./output/images/comparing/cars-br/img_000180.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000181.jpg saved at ./output/images/comparing/cars-br/img_000181.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000182.jpg saved at ./output/images/comparing/cars-br/img_000182.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000183.jpg saved at ./output/images/comparing/cars-br/img_000183.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000184.jpg saved at ./output/images/comparing/cars-br/img_000184.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000185.jpg saved at ./output/images/comparing/cars-br/img_000185.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000186.jpg saved at ./output/images/comparing/cars-br/img_000186.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000187.jpg saved at ./output/images/comparing/cars-br/img_000187.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000188.jpg saved at ./output/images/comparing/cars-br/img_000188.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000189.jpg saved at ./output/images/comparing/cars-br/img_000189.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000190.jpg saved at ./output/images/comparing/cars-br/img_000190.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000191.jpg saved at ./output/images/comparing/cars-br/img_000191.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000192.jpg saved at ./output/images/comparing/cars-br/img_000192.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000193.jpg saved at ./output/images/comparing/cars-br/img_000193.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000194.jpg saved at ./output/images/comparing/cars-br/img_000194.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000195.jpg saved at ./output/images/comparing/cars-br/img_000195.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000196.jpg saved at ./output/images/comparing/cars-br/img_000196.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000197.jpg saved at ./output/images/comparing/cars-br/img_000197.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000198.jpg saved at ./output/images/comparing/cars-br/img_000198.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000199.jpg saved at ./output/images/comparing/cars-br/img_000199.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000200.jpg saved at ./output/images/comparing/cars-br/img_000200.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000201.jpg saved at ./output/images/comparing/cars-br/img_000201.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000202.jpg saved at ./output/images/comparing/cars-br/img_000202.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000203.jpg saved at ./output/images/comparing/cars-br/img_000203.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000204.jpg saved at ./output/images/comparing/cars-br/img_000204.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000205.jpg saved at ./output/images/comparing/cars-br/img_000205.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000206.jpg saved at ./output/images/comparing/cars-br/img_000206.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000207.jpg saved at ./output/images/comparing/cars-br/img_000207.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000208.jpg saved at ./output/images/comparing/cars-br/img_000208.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000209.jpg saved at ./output/images/comparing/cars-br/img_000209.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000210.jpg saved at ./output/images/comparing/cars-br/img_000210.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000211.jpg saved at ./output/images/comparing/cars-br/img_000211.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000212.jpg saved at ./output/images/comparing/cars-br/img_000212.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000213.jpg saved at ./output/images/comparing/cars-br/img_000213.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000214.jpg saved at ./output/images/comparing/cars-br/img_000214.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000215.jpg saved at ./output/images/comparing/cars-br/img_000215.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000216.jpg saved at ./output/images/comparing/cars-br/img_000216.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000217.jpg saved at ./output/images/comparing/cars-br/img_000217.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000218.jpg saved at ./output/images/comparing/cars-br/img_000218.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000219.jpg saved at ./output/images/comparing/cars-br/img_000219.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000220.jpg saved at ./output/images/comparing/cars-br/img_000220.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000221.jpg saved at ./output/images/comparing/cars-br/img_000221.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000222.jpg saved at ./output/images/comparing/cars-br/img_000222.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000223.jpg saved at ./output/images/comparing/cars-br/img_000223.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000224.jpg saved at ./output/images/comparing/cars-br/img_000224.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000225.jpg saved at ./output/images/comparing/cars-br/img_000225.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000226.jpg saved at ./output/images/comparing/cars-br/img_000226.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000227.jpg saved at ./output/images/comparing/cars-br/img_000227.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000228.jpg saved at ./output/images/comparing/cars-br/img_000228.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000229.jpg saved at ./output/images/comparing/cars-br/img_000229.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000230.jpg saved at ./output/images/comparing/cars-br/img_000230.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000231.jpg saved at ./output/images/comparing/cars-br/img_000231.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000232.jpg saved at ./output/images/comparing/cars-br/img_000232.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000233.jpg saved at ./output/images/comparing/cars-br/img_000233.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000234.jpg saved at ./output/images/comparing/cars-br/img_000234.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000235.jpg saved at ./output/images/comparing/cars-br/img_000235.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000236.jpg saved at ./output/images/comparing/cars-br/img_000236.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000237.jpg saved at ./output/images/comparing/cars-br/img_000237.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000238.jpg saved at ./output/images/comparing/cars-br/img_000238.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000239.jpg saved at ./output/images/comparing/cars-br/img_000239.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000240.jpg saved at ./output/images/comparing/cars-br/img_000240.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000241.jpg saved at ./output/images/comparing/cars-br/img_000241.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000242.jpg saved at ./output/images/comparing/cars-br/img_000242.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000243.jpg saved at ./output/images/comparing/cars-br/img_000243.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000244.jpg saved at ./output/images/comparing/cars-br/img_000244.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000245.jpg saved at ./output/images/comparing/cars-br/img_000245.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000246.jpg saved at ./output/images/comparing/cars-br/img_000246.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000247.jpg saved at ./output/images/comparing/cars-br/img_000247.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000248.jpg saved at ./output/images/comparing/cars-br/img_000248.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000249.jpg saved at ./output/images/comparing/cars-br/img_000249.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000250.jpg saved at ./output/images/comparing/cars-br/img_000250.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000251.jpg saved at ./output/images/comparing/cars-br/img_000251.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000252.jpg saved at ./output/images/comparing/cars-br/img_000252.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000253.jpg saved at ./output/images/comparing/cars-br/img_000253.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000254.jpg saved at ./output/images/comparing/cars-br/img_000254.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000255.jpg saved at ./output/images/comparing/cars-br/img_000255.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000256.jpg saved at ./output/images/comparing/cars-br/img_000256.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000257.jpg saved at ./output/images/comparing/cars-br/img_000257.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000258.jpg saved at ./output/images/comparing/cars-br/img_000258.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000259.jpg saved at ./output/images/comparing/cars-br/img_000259.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000260.jpg saved at ./output/images/comparing/cars-br/img_000260.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000261.jpg saved at ./output/images/comparing/cars-br/img_000261.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000262.jpg saved at ./output/images/comparing/cars-br/img_000262.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000263.jpg saved at ./output/images/comparing/cars-br/img_000263.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000264.jpg saved at ./output/images/comparing/cars-br/img_000264.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000265.jpg saved at ./output/images/comparing/cars-br/img_000265.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000266.jpg saved at ./output/images/comparing/cars-br/img_000266.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000267.jpg saved at ./output/images/comparing/cars-br/img_000267.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000268.jpg saved at ./output/images/comparing/cars-br/img_000268.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000269.jpg saved at ./output/images/comparing/cars-br/img_000269.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000270.jpg saved at ./output/images/comparing/cars-br/img_000270.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000271.jpg saved at ./output/images/comparing/cars-br/img_000271.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000272.jpg saved at ./output/images/comparing/cars-br/img_000272.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000273.jpg saved at ./output/images/comparing/cars-br/img_000273.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000274.jpg saved at ./output/images/comparing/cars-br/img_000274.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000275.jpg saved at ./output/images/comparing/cars-br/img_000275.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000276.jpg saved at ./output/images/comparing/cars-br/img_000276.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000277.jpg saved at ./output/images/comparing/cars-br/img_000277.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000278.jpg saved at ./output/images/comparing/cars-br/img_000278.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000279.jpg saved at ./output/images/comparing/cars-br/img_000279.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000280.jpg saved at ./output/images/comparing/cars-br/img_000280.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000281.jpg saved at ./output/images/comparing/cars-br/img_000281.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000282.jpg saved at ./output/images/comparing/cars-br/img_000282.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000283.jpg saved at ./output/images/comparing/cars-br/img_000283.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000284.jpg saved at ./output/images/comparing/cars-br/img_000284.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000285.jpg saved at ./output/images/comparing/cars-br/img_000285.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000286.jpg saved at ./output/images/comparing/cars-br/img_000286.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000287.jpg saved at ./output/images/comparing/cars-br/img_000287.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000288.jpg saved at ./output/images/comparing/cars-br/img_000288.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000289.jpg saved at ./output/images/comparing/cars-br/img_000289.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000290.jpg saved at ./output/images/comparing/cars-br/img_000290.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000291.jpg saved at ./output/images/comparing/cars-br/img_000291.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000292.jpg saved at ./output/images/comparing/cars-br/img_000292.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000293.jpg saved at ./output/images/comparing/cars-br/img_000293.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_000294.jpg saved at ./output/images/comparing/cars-br/img_000294.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# ...
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004883.jpg saved at ./output/images/comparing/cars-br/img_004883.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004884.jpg saved at ./output/images/comparing/cars-br/img_004884.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004885.jpg saved at ./output/images/comparing/cars-br/img_004885.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004886.jpg saved at ./output/images/comparing/cars-br/img_004886.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004887.jpg saved at ./output/images/comparing/cars-br/img_004887.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004888.jpg saved at ./output/images/comparing/cars-br/img_004888.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004889.jpg saved at ./output/images/comparing/cars-br/img_004889.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004890.jpg saved at ./output/images/comparing/cars-br/img_004890.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004891.jpg saved at ./output/images/comparing/cars-br/img_004891.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004892.jpg saved at ./output/images/comparing/cars-br/img_004892.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004893.jpg saved at ./output/images/comparing/cars-br/img_004893.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004894.jpg saved at ./output/images/comparing/cars-br/img_004894.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004895.jpg saved at ./output/images/comparing/cars-br/img_004895.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004896.jpg saved at ./output/images/comparing/cars-br/img_004896.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004897.jpg saved at ./output/images/comparing/cars-br/img_004897.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004898.jpg saved at ./output/images/comparing/cars-br/img_004898.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004899.jpg saved at ./output/images/comparing/cars-br/img_004899.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004900.jpg saved at ./output/images/comparing/cars-br/img_004900.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004901.jpg saved at ./output/images/comparing/cars-br/img_004901.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004902.jpg saved at ./output/images/comparing/cars-br/img_004902.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004903.jpg saved at ./output/images/comparing/cars-br/img_004903.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004904.jpg saved at ./output/images/comparing/cars-br/img_004904.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004905.jpg saved at ./output/images/comparing/cars-br/img_004905.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004906.jpg saved at ./output/images/comparing/cars-br/img_004906.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004907.jpg saved at ./output/images/comparing/cars-br/img_004907.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004908.jpg saved at ./output/images/comparing/cars-br/img_004908.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004909.jpg saved at ./output/images/comparing/cars-br/img_004909.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004910.jpg saved at ./output/images/comparing/cars-br/img_004910.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004911.jpg saved at ./output/images/comparing/cars-br/img_004911.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004912.jpg saved at ./output/images/comparing/cars-br/img_004912.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004913.jpg saved at ./output/images/comparing/cars-br/img_004913.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004914.jpg saved at ./output/images/comparing/cars-br/img_004914.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004915.jpg saved at ./output/images/comparing/cars-br/img_004915.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004916.jpg saved at ./output/images/comparing/cars-br/img_004916.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004917.jpg saved at ./output/images/comparing/cars-br/img_004917.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004918.jpg saved at ./output/images/comparing/cars-br/img_004918.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004919.jpg saved at ./output/images/comparing/cars-br/img_004919.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004920.jpg saved at ./output/images/comparing/cars-br/img_004920.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004921.jpg saved at ./output/images/comparing/cars-br/img_004921.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004922.jpg saved at ./output/images/comparing/cars-br/img_004922.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004923.jpg saved at ./output/images/comparing/cars-br/img_004923.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004924.jpg saved at ./output/images/comparing/cars-br/img_004924.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004925.jpg saved at ./output/images/comparing/cars-br/img_004925.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004926.jpg saved at ./output/images/comparing/cars-br/img_004926.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004927.jpg saved at ./output/images/comparing/cars-br/img_004927.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004928.jpg saved at ./output/images/comparing/cars-br/img_004928.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004929.jpg saved at ./output/images/comparing/cars-br/img_004929.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004930.jpg saved at ./output/images/comparing/cars-br/img_004930.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004931.jpg saved at ./output/images/comparing/cars-br/img_004931.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004932.jpg saved at ./output/images/comparing/cars-br/img_004932.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004933.jpg saved at ./output/images/comparing/cars-br/img_004933.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004934.jpg saved at ./output/images/comparing/cars-br/img_004934.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004935.jpg saved at ./output/images/comparing/cars-br/img_004935.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004936.jpg saved at ./output/images/comparing/cars-br/img_004936.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004937.jpg saved at ./output/images/comparing/cars-br/img_004937.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004938.jpg saved at ./output/images/comparing/cars-br/img_004938.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004939.jpg saved at ./output/images/comparing/cars-br/img_004939.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004940.jpg saved at ./output/images/comparing/cars-br/img_004940.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004941.jpg saved at ./output/images/comparing/cars-br/img_004941.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004942.jpg saved at ./output/images/comparing/cars-br/img_004942.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004943.jpg saved at ./output/images/comparing/cars-br/img_004943.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004944.jpg saved at ./output/images/comparing/cars-br/img_004944.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004945.jpg saved at ./output/images/comparing/cars-br/img_004945.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004946.jpg saved at ./output/images/comparing/cars-br/img_004946.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004947.jpg saved at ./output/images/comparing/cars-br/img_004947.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004948.jpg saved at ./output/images/comparing/cars-br/img_004948.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004949.jpg saved at ./output/images/comparing/cars-br/img_004949.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004950.jpg saved at ./output/images/comparing/cars-br/img_004950.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004951.jpg saved at ./output/images/comparing/cars-br/img_004951.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004952.jpg saved at ./output/images/comparing/cars-br/img_004952.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004953.jpg saved at ./output/images/comparing/cars-br/img_004953.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004954.jpg saved at ./output/images/comparing/cars-br/img_004954.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004955.jpg saved at ./output/images/comparing/cars-br/img_004955.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004956.jpg saved at ./output/images/comparing/cars-br/img_004956.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004957.jpg saved at ./output/images/comparing/cars-br/img_004957.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004958.jpg saved at ./output/images/comparing/cars-br/img_004958.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004959.jpg saved at ./output/images/comparing/cars-br/img_004959.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004960.jpg saved at ./output/images/comparing/cars-br/img_004960.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004961.jpg saved at ./output/images/comparing/cars-br/img_004961.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004962.jpg saved at ./output/images/comparing/cars-br/img_004962.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004963.jpg saved at ./output/images/comparing/cars-br/img_004963.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004964.jpg saved at ./output/images/comparing/cars-br/img_004964.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004965.jpg saved at ./output/images/comparing/cars-br/img_004965.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004966.jpg saved at ./output/images/comparing/cars-br/img_004966.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004967.jpg saved at ./output/images/comparing/cars-br/img_004967.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004968.jpg saved at ./output/images/comparing/cars-br/img_004968.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004969.jpg saved at ./output/images/comparing/cars-br/img_004969.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004970.jpg saved at ./output/images/comparing/cars-br/img_004970.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004971.jpg saved at ./output/images/comparing/cars-br/img_004971.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004972.jpg saved at ./output/images/comparing/cars-br/img_004972.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004973.jpg saved at ./output/images/comparing/cars-br/img_004973.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004974.jpg saved at ./output/images/comparing/cars-br/img_004974.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004975.jpg saved at ./output/images/comparing/cars-br/img_004975.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004976.jpg saved at ./output/images/comparing/cars-br/img_004976.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004977.jpg saved at ./output/images/comparing/cars-br/img_004977.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004978.jpg saved at ./output/images/comparing/cars-br/img_004978.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004979.jpg saved at ./output/images/comparing/cars-br/img_004979.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004980.jpg saved at ./output/images/comparing/cars-br/img_004980.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004981.jpg saved at ./output/images/comparing/cars-br/img_004981.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004982.jpg saved at ./output/images/comparing/cars-br/img_004982.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004983.jpg saved at ./output/images/comparing/cars-br/img_004983.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004984.jpg saved at ./output/images/comparing/cars-br/img_004984.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004985.jpg saved at ./output/images/comparing/cars-br/img_004985.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004986.jpg saved at ./output/images/comparing/cars-br/img_004986.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004987.jpg saved at ./output/images/comparing/cars-br/img_004987.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004988.jpg saved at ./output/images/comparing/cars-br/img_004988.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004989.jpg saved at ./output/images/comparing/cars-br/img_004989.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004990.jpg saved at ./output/images/comparing/cars-br/img_004990.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004991.jpg saved at ./output/images/comparing/cars-br/img_004991.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004992.jpg saved at ./output/images/comparing/cars-br/img_004992.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004993.jpg saved at ./output/images/comparing/cars-br/img_004993.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004994.jpg saved at ./output/images/comparing/cars-br/img_004994.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004995.jpg saved at ./output/images/comparing/cars-br/img_004995.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004996.jpg saved at ./output/images/comparing/cars-br/img_004996.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004997.jpg saved at ./output/images/comparing/cars-br/img_004997.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004998.jpg saved at ./output/images/comparing/cars-br/img_004998.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_004999.jpg saved at ./output/images/comparing/cars-br/img_004999.jpg
#
# <function combine_images_side_by_side at 0x000001FADFF308B0>
# img_005000.jpg saved at ./output/images/comparing/cars-br/img_005000.jpg
